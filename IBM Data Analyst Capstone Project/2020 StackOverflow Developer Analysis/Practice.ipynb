# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
stackOverflow_account_df = df[['SOAccount','Country']]

# %%
stackOverflow_account_df
# Out:
#       SOAccount             Country
# 0            No             Germany
# 1           Yes      United Kingdom
# 2           Yes  Russian Federation
# 3           Yes             Albania
# 4           Yes       United States
# ...         ...                 ...
# 64456       NaN       United States
# 64457       NaN             Morocco
# 64458       NaN            Viet Nam
# 64459       NaN              Poland
# 64460       NaN               Spain
#
# [64461 rows x 2 columns]

# %%
stackOverflow_account_df.head(50)
# Out:
#    SOAccount             Country
# 0         No             Germany
# 1        Yes      United Kingdom
# 2        Yes  Russian Federation
# 3        Yes             Albania
# 4        Yes       United States
# 5        Yes             Germany
# 6        Yes               India
# 7        Yes       United States
# 8        Yes             Tunisia
# 9        Yes      United Kingdom
# 10       Yes      United Kingdom
# 11       Yes               Spain
# 12       Yes         Netherlands
# 13       Yes       United States
# 14        No              France
# 15       Yes      United Kingdom
# 16       Yes       United States
# 17       Yes       United States
# 18       Yes       United States
# 19       Yes               Spain
# 20       Yes             Belgium
# 21       Yes               India
# 22       Yes             Germany
# 23       Yes             Germany
# 24       Yes            Portugal
# 25       Yes              Canada
# 26       Yes       United States
# ...

# %%
x = stackOverflow_account_df[stackOverflow_account_df['SOAccount'] == 'Yes'].value_counts()
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
import folium
countries_geojson = 'https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json'

# %%
m = folium.Map(location=[30, 0], zoom_start=2)

folium.Choropleth(
    geo_data=countries_geojson,
    data=stackOverflow_account_df,
    columns=["Country", "Count"],
    key_on="feature.properties.name",
    threshold_scale=[1, 30, 100, 300, 1_000, 3_000, 10_000, 13_000],
    fill_color="OrRd",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Respondents",
).add_to(m)

m
